# %% [markdown]
# # RAG
#
# In diesem Notebook können Sie sich selbst an verschiedenen Einstellungen erproben und Ergebnisse vergleichen.

# %%
from recipes.rag.rag_service import RAGService
import os
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
rag_service = RAGService(embedding_model="text-embedding-3-small", query_model="gpt-4o", db_url=os.getenv("MONGO_DB_URL"), collection=os.getenv("MONGO_COLLECTION_NAME_RECIPES")) # type: ignore

# %%
rag_service.setup()
# Out:
# 0it [00:30, ?it/s]
# ---------------------------------------------------------------------------
# ServerSelectionTimeoutError               Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 rag_service.setup()
#
# File ~/IdeaProjects/bootcamp_handson_genai_mlops/src/recipes/rag/rag_service.py:49, in RAGService.setup(self)
#      46 def setup(self):
#      47     documents = self.retrieve_documents()
# ---> 49     self.embed_documents(documents)
#      51     self.collection.create_search_index(self.create_search_index_model())
#
# File ~/IdeaProjects/bootcamp_handson_genai_mlops/src/recipes/rag/rag_service.py:72, in RAGService.embed_documents(self, documents)
#      70 # Generate the list of bulk write operations
#      71 operations = []
# ---> 72 for doc in tqdm(documents):
#      73     ingredients = "".join(doc["ingredients"])
#      74     # Generate embeddings for this document
#
# File ~/IdeaProjects/bootcamp_handson_genai_mlops/.venv/lib/python3.13/site-packages/tqdm/std.py:1181, in tqdm.__iter__(self)
#    1178 time = self._time
#    1180 try:
# -> 1181     for obj in iterable:
#    1182         yield obj
#    1183         # Update and possibly print the progressbar.
#    1184         # Note: does not call self.update(1) for speed optimisation.
#
# File ~/IdeaProjects/bootcamp_handson_genai_mlops/.venv/lib/python3.13/site-packages/pymongo/synchronous/cursor.py:1289, in Cursor.__next__(self)
#    1288 def __next__(self) -> _DocumentType:
# -> 1289     return self.next()
#
# File ~/IdeaProjects/bootcamp_handson_genai_mlops/.venv/lib/python3.13/site-packages/pymongo/synchronous/cursor.py:1265, in Cursor.next(self)
#    1263 if self._empty:
#    1264     raise StopIteration
# -> 1265 if len(self._data) or self._refresh():
#    1266     return self._data.popleft()
#    1267 else:
#
# File ~/IdeaProjects/bootcamp_handson_genai_mlops/.venv/lib/python3.13/site-packages/pymongo/synchronous/cursor.py:1213, in Cursor._refresh(self)
#    1191         raise InvalidOperation(
#    1192             "Passing a 'hint' is required when using the min/max query"
#    1193             " option to ensure the query utilizes the correct index"
#    1194         )
#    1195     q = self._query_class(
#    1196         self._query_flags,
#    1197         self._collection.database.name,
#    (...)   1211         self._exhaust,
#    1212     )
# -> 1213     self._send_message(q)
#    1214 elif self._id:  # Get More
#    1215     if self._limit:
#
# File ~/IdeaProjects/bootcamp_handson_genai_mlops/.venv/lib/python3.13/site-packages/pymongo/synchronous/cursor.py:1108, in Cursor._send_message(self, operation)
#    1105     raise InvalidOperation("exhaust cursors do not support auto encryption")
#    1107 try:
# -> 1108     response = client._run_operation(
#    1109         operation, self._unpack_response, address=self._address
#    1110     )
#    1111 except OperationFailure as exc:
#    1112     if exc.code in _CURSOR_CLOSED_ERRORS or self._exhaust:
#    1113         # Don't send killCursors because the cursor is already closed.
#
# File ~/IdeaProjects/bootcamp_handson_genai_mlops/.venv/lib/python3.13/site-packages/pymongo/_csot.py:125, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     123         with _TimeoutContext(timeout):
#     124             return func(self, *args, **kwargs)
# --> 125 return func(self, *args, **kwargs)
#
# File ~/IdeaProjects/bootcamp_handson_genai_mlops/.venv/lib/python3.13/site-packages/pymongo/synchronous/mongo_client.py:1938, in MongoClient._run_operation(self, operation, unpack_res, address)
#    1928     operation.reset()  # Reset op in case of retry.
#    1929     return server.run_operation(
#    1930         conn,
#    1931         operation,
#    (...)   1935         self,
#    1936     )
# -> 1938 return self._retryable_read(
#    1939     _cmd,
#    1940     operation.read_preference,
#    1941     operation.session,  # type: ignore[arg-type]
#    1942     address=address,
#    1943     retryable=isinstance(operation, _Query),
#    1944     operation=operation.name,
#    1945 )
#
# File ~/IdeaProjects/bootcamp_handson_genai_mlops/.venv/lib/python3.13/site-packages/pymongo/synchronous/mongo_client.py:2048, in MongoClient._retryable_read(self, func, read_pref, session, operation, address, retryable, operation_id)
#    2044 retryable = bool(
#    2045     retryable and self.options.retry_reads and not (session and session.in_transaction)
#    2046 )
#    2047 with self._tmp_session(session) as s:
# -> 2048     return self._retry_internal(
#    2049         func,
#    2050         s,
#    2051         None,
#    2052         operation,
#    2053         is_read=True,
#    2054         address=address,
#    2055         read_pref=read_pref,
#    2056         retryable=retryable,
#    2057         operation_id=operation_id,
#    2058     )
#
# File ~/IdeaProjects/bootcamp_handson_genai_mlops/.venv/lib/python3.13/site-packages/pymongo/_csot.py:125, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     123         with _TimeoutContext(timeout):
#     124             return func(self, *args, **kwargs)
# --> 125 return func(self, *args, **kwargs)
#
# File ~/IdeaProjects/bootcamp_handson_genai_mlops/.venv/lib/python3.13/site-packages/pymongo/synchronous/mongo_client.py:2014, in MongoClient._retry_internal(self, func, session, bulk, operation, is_read, address, read_pref, retryable, operation_id)
#    1977 @_csot.apply
#    1978 def _retry_internal(
#    1979     self,
#    (...)   1988     operation_id: Optional[int] = None,
#    1989 ) -> T:
#    1990     """Internal retryable helper for all client transactions.
#    1991
#    1992     :param func: Callback function we want to retry
#    (...)   2001     :return: Output of the calling func()
#    2002     """
#    2003     return _ClientConnectionRetryable(
#    2004         mongo_client=self,
#    2005         func=func,
#    2006         bulk=bulk,
#    2007         operation=operation,
#    2008         is_read=is_read,
#    2009         session=session,
#    2010         read_pref=read_pref,
#    2011         address=address,
#    2012         retryable=retryable,
#    2013         operation_id=operation_id,
# -> 2014     ).run()
#
# File ~/IdeaProjects/bootcamp_handson_genai_mlops/.venv/lib/python3.13/site-packages/pymongo/synchronous/mongo_client.py:2763, in _ClientConnectionRetryable.run(self)
#    2761 self._check_last_error(check_csot=True)
#    2762 try:
# -> 2763     return self._read() if self._is_read else self._write()
#    2764 except ServerSelectionTimeoutError:
#    2765     # The application may think the write was never attempted
#    2766     # if we raise ServerSelectionTimeoutError on the retry
#    2767     # attempt. Raise the original exception instead.
#    2768     self._check_last_error()
#
# File ~/IdeaProjects/bootcamp_handson_genai_mlops/.venv/lib/python3.13/site-packages/pymongo/synchronous/mongo_client.py:2908, in _ClientConnectionRetryable._read(self)
#    2903 def _read(self) -> T:
#    2904     """Wrapper method for read-type retryable client executions
#    2905
#    2906     :return: Output for func()'s call
#    2907     """
# -> 2908     self._server = self._get_server()
#    2909     assert self._read_pref is not None, "Read Preference required on read calls"
#    2910     with self._client._conn_from_server(self._read_pref, self._server, self._session) as (
#    2911         conn,
#    2912         read_pref,
#    2913     ):
#
# File ~/IdeaProjects/bootcamp_handson_genai_mlops/.venv/lib/python3.13/site-packages/pymongo/synchronous/mongo_client.py:2856, in _ClientConnectionRetryable._get_server(self)
#    2851 def _get_server(self) -> Server:
#    2852     """Retrieves a server object based on provided object context
#    2853
#    2854     :return: Abstraction to connect to server
#    2855     """
# -> 2856     return self._client._select_server(
#    2857         self._server_selector,
#    2858         self._session,
#    2859         self._operation,
#    2860         address=self._address,
#    2861         deprioritized_servers=self._deprioritized_servers,
#    2862         operation_id=self._operation_id,
#    2863     )
#
# File ~/IdeaProjects/bootcamp_handson_genai_mlops/.venv/lib/python3.13/site-packages/pymongo/synchronous/mongo_client.py:1833, in MongoClient._select_server(self, server_selector, session, operation, address, deprioritized_servers, operation_id)
#    1831             raise AutoReconnect("server %s:%s no longer available" % address)  # noqa: UP031
#    1832     else:
# -> 1833         server = topology.select_server(
#    1834             server_selector,
#    1835             operation,
#    1836             deprioritized_servers=deprioritized_servers,
#    1837             operation_id=operation_id,
#    1838         )
#    1839     return server
#    1840 except PyMongoError as exc:
#    1841     # Server selection errors in a transaction are transient.
#
# File ~/IdeaProjects/bootcamp_handson_genai_mlops/.venv/lib/python3.13/site-packages/pymongo/synchronous/topology.py:428, in Topology.select_server(self, selector, operation, server_selection_timeout, address, deprioritized_servers, operation_id)
#     418 def select_server(
#     419     self,
#     420     selector: Callable[[Selection], Selection],
#    (...)    425     operation_id: Optional[int] = None,
#     426 ) -> Server:
#     427     """Like select_servers, but choose a random server if several match."""
# --> 428     server = self._select_server(
#     429         selector,
#     430         operation,
#     431         server_selection_timeout,
#     432         address,
#     433         deprioritized_servers,
#     434         operation_id=operation_id,
#     435     )
#     436     if _csot.get_timeout():
#     437         _csot.set_rtt(server.description.min_round_trip_time)
#
# File ~/IdeaProjects/bootcamp_handson_genai_mlops/.venv/lib/python3.13/site-packages/pymongo/synchronous/topology.py:402, in Topology._select_server(self, selector, operation, server_selection_timeout, address, deprioritized_servers, operation_id)
#     393 def _select_server(
#     394     self,
#     395     selector: Callable[[Selection], Selection],
#    (...)    400     operation_id: Optional[int] = None,
#     401 ) -> Server:
# --> 402     servers = self.select_servers(
#     403         selector,
#     404         operation,
#     405         server_selection_timeout,
#     406         address,
#     407         operation_id,
#     408         deprioritized_servers,
#     409     )
#     410     if len(servers) == 1:
#     411         return servers[0]
#
# File ~/IdeaProjects/bootcamp_handson_genai_mlops/.venv/lib/python3.13/site-packages/pymongo/synchronous/topology.py:298, in Topology.select_servers(self, selector, operation, server_selection_timeout, address, operation_id, deprioritized_servers)
#     295     self.cleanup_monitors()
#     297 with self._lock:
# --> 298     server_descriptions = self._select_servers_loop(
#     299         selector,
#     300         server_timeout,
#     301         operation,
#     302         operation_id,
#     303         address,
#     304         deprioritized_servers=deprioritized_servers,
#     305     )
#     307     return [
#     308         cast(Server, self.get_server_by_address(sd.address)) for sd in server_descriptions
#     309     ]
#
# File ~/IdeaProjects/bootcamp_handson_genai_mlops/.venv/lib/python3.13/site-packages/pymongo/synchronous/topology.py:359, in Topology._select_servers_loop(self, selector, timeout, operation, operation_id, address, deprioritized_servers)
#     348     if _SERVER_SELECTION_LOGGER.isEnabledFor(logging.DEBUG):
#     349         _debug_log(
#     350             _SERVER_SELECTION_LOGGER,
#     351             message=_ServerSelectionStatusMessage.FAILED,
#    (...)    357             failure=self._error_message(selector),
#     358         )
# --> 359     raise ServerSelectionTimeoutError(
#     360         f"{self._error_message(selector)}, Timeout: {timeout}s, Topology Description: {self.description!r}"
#     361     )
#     363 if not logged_waiting:
#     364     _debug_log(
#     365         _SERVER_SELECTION_LOGGER,
#     366         message=_ServerSelectionStatusMessage.WAITING,
#    (...)    372         remainingTimeMS=int(1000 * (end_time - time.monotonic())),
#     373     )
#
# ServerSelectionTimeoutError: SSL handshake failed: ac-duzajgp-shard-00-02.3vg35ok.mongodb.net:27017: [SSL: TLSV1_ALERT_INTERNAL_ERROR] tlsv1 alert internal error (_ssl.c:1018) (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms),SSL handshake failed: ac-duzajgp-shard-00-00.3vg35ok.mongodb.net:27017: [SSL: TLSV1_ALERT_INTERNAL_ERROR] tlsv1 alert internal error (_ssl.c:1018) (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms),SSL handshake failed: ac-duzajgp-shard-00-01.3vg35ok.mongodb.net:27017: [SSL: TLSV1_ALERT_INTERNAL_ERROR] tlsv1 alert internal error (_ssl.c:1018) (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms), Timeout: 30s, Topology Description: <TopologyDescription id: 69afedacce8bb0b134830f9c, topology_type: ReplicaSetNoPrimary, servers: [<ServerDescription ('ac-duzajgp-shard-00-00.3vg35ok.mongodb.net', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('SSL handshake failed: ac-duzajgp-shard-00-00.3vg35ok.mongodb.net:27017: [SSL: TLSV1_ALERT_INTERNAL_ERROR] tlsv1 alert internal error (_ssl.c:1018) (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')>, <ServerDescription ('ac-duzajgp-shard-00-01.3vg35ok.mongodb.net', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('SSL handshake failed: ac-duzajgp-shard-00-01.3vg35ok.mongodb.net:27017: [SSL: TLSV1_ALERT_INTERNAL_ERROR] tlsv1 alert internal error (_ssl.c:1018) (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')>, <ServerDescription ('ac-duzajgp-shard-00-02.3vg35ok.mongodb.net', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('SSL handshake failed: ac-duzajgp-shard-00-02.3vg35ok.mongodb.net:27017: [SSL: TLSV1_ALERT_INTERNAL_ERROR] tlsv1 alert internal error (_ssl.c:1018) (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')>]>

# %%
# Hier Anfrage festlegen

anfrage = "Ich habe eine Party und möchte etwas leckeres zum Naschen anbieten. Ich habe aber nicht viel Zeit und keine Lust auf viel Aufwand. Ich habe aber auch keine Lust auf Pizza"

antwort = rag_service.generate_response(anfrage)
print(antwort)
