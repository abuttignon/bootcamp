# %% [markdown]
# # Prompt Engineering
#
# In diesem Notebook können Sie sich selbst an verschiedenen Prompts erproben um das gewünschte Ergebnis zu erhalten. Sie finden eine Vorlage für mögliche Prompts in data/prompts.py. Sie können diese in der vorgesehenen Zelle einfügen oder selbst eigene Prompts erstellen.

# %% [markdown]
# ## Prompt Versions
#
# Six system prompt versions in `data/raw/prompts_recipes.py`, each demonstrating a different technique:
#
# | Version | Technique | What changed |
# |---------|-----------|--------------|
# | v1 | Basic instruction | Simple "be a helpful chef" prompt |
# | v2 | Detailed constraints | Added metric-aware instructions |
# | v3 | Persona + structure | Chef persona with structured output |
# | v4 | Self-validation | 3-step self-check before answering |
# | v5 | Dual variant | Two outputs: best use of ingredients vs. refusal with suggestions |
# | v6 | Strict JSON schema | Full JSON schema enforcement, ingredient tracking, impossibility detection |
#
# v6 (latest) enforces a strict JSON output schema — the model validates ingredients, tracks what's used, and explicitly flags when a recipe is not possible with the given inputs.m

# %%
import data.raw.prompts_recipes as prompts_recipes

SYSTEM_PROMPT = prompts_recipes.SYSTEM_INSTRUCTIONS_1

# TODO Hier geben sie dem Modell genaue Instruktionen um gewünschtes Verhalten zu erziehlen

# SYSTEM_PROMPT = """
# Du bist ein professioneller Koch und hilfst mir dabei ein passendes Gericht zu finden.
# """

print(SYSTEM_PROMPT)
# Out:
# Du bist ein Rezeptgenerator. Verwende nur die Zutaten, die dir der Nutzer gibt, und nenne ein Rezept.

# %%
from recipes.prompt_engineering.prompt_engineering_service import PromptEngineeringService
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
# TODO Hier können Sie die Temperature, also den Kreativitätsgrad des Modells anpassen.

temperature = 0.2

pes = PromptEngineeringService(temperature=temperature, system_prompt=SYSTEM_PROMPT)

# %%
Zutaten = ["Tomaten", "Zucchini", "Gurke", "Zwiebeln", "Kartoffeln", "Paprika", "Kichererbsen", "Kidneybohnen"]

# Wenn Sie finden, dass die Anfrage nicht gut genug ist, können Sie sie hier nach belieben anpassen.

anfrage = f"Finde mir ein Gericht mit folgenden Zutaten: {Zutaten}"

# %%
antwort = pes.answer_anfrage(anfrage)
print(antwort)
# Out:
# Mit den von dir genannten Zutaten kannst du ein leckeres und nahrhaftes Gemüse-Curry zubereiten. Hier ist ein einfaches Rezeptvorschlag:
#
# ### Gemüse-Curry mit Kichererbsen und Kidneybohnen
#
# #### Zutaten:
# - 2 Tomaten, gewürfelt
# - 1 Zucchini, in Scheiben geschnitten
# - 1 Gurke, geschält, entkernt und in Würfel geschnitten (optional, da Gurke meist roh verwendet wird)
# - 1 Zwiebel, fein gehackt
# - 2 Kartoffeln, geschält und gewürfelt
# - 1 Paprika, in Streifen geschnitten
# - 1 Dose Kichererbsen, abgetropft und abgespült
# - 1 Dose Kidneybohnen, abgetropft und abgespült
# - 2 EL Pflanzenöl
# - 2 Knoblauchzehen, gehackt
# - 1 TL Ingwer, gerieben
# - 1 TL Kreuzkümmel
# - 1 TL Korianderpulver
# - 1 TL Kurkuma
# - 1 TL Paprikapulver
# - 400 ml Kokosmilch
# - Salz und Pfeffer nach Geschmack
# - Frische Korianderblätter zum Garnieren
#
# #### Zubereitung:
# 1. Erhitze das Pflanzenöl in einem großen Topf bei mittlerer Hitze. Füge die gehackte Zwiebel hinzu und brate sie an, bis sie glasig ist.
# 2. Gib den Knoblauch und den Ingwer hinzu und brate sie für etwa 1 Minute mit.
# 3. Füge die Gewürze (Kreuzkümmel, Korianderpulver, Kurkuma, Paprikapulver) hinzu und röste sie kurz an, bis sie duften.
# 4. Gib die gewürfelten Kartoffeln, Tomaten, Zucchini und Paprika in den Topf. Rühre alles gut um, sodass das Gemüse mit den Gewürzen bedeckt ist.
# 5. Gieße die Kokosmilch hinzu und bringe alles zum Kochen. Reduziere die Hitze und lasse das Curry etwa 15-20 Minuten köcheln, bis die Kartoffeln weich sind.
# 6. Füge die Kichererbsen und Kidneybohnen hinzu und koche das Curry weitere 5 Minuten, bis alles gut erhitzt ist. Schmecke mit Salz und Pfeffer ab.
# 7. Optional: Wenn du die Gurke verwenden möchtest, kannst du sie roh als erfrischende Beilage servieren oder ganz am Ende kurz unter das Curry mischen.
# 8. Garniere das Curry mit frischen Korianderblättern und serviere es heiß, idealerweise mit Reis oder Naan-Brot.
#
# Guten Appetit!
